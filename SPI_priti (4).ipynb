# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.graph_objs as go
from plotly.offline import iplot

# %%
spi=pd.read_csv("spi.csv")

# %%
spi.head()
# Out:
#        Country  Happiness score  Whisker-high  Whisker-low   GDP per capita  \
# 0  Afghanistan            3.794         3.874        3.714            0.401
# 1      Albania            4.644         4.752        4.536            0.996
# 2      Algeria            5.872         5.978        5.766            1.092
# 3       Angola            3.795         3.952        3.638            0.858
# 4    Argentina            6.599         6.690        6.508            1.185
#
#     Social support  Healthy life expectancy  Freedom to make life choices  \
# 0            0.582                    0.181                         0.106
# 1            0.804                    0.731                         0.381
# 2            1.146                    0.618                         0.233
# 3            1.104                    0.050                         0.000
# 4            1.440                    0.695                         0.495
#
# ...

# %%
spi.describe()
# Out:
#        Happiness score  Whisker-high  Whisker-low   GDP per capita  \
# count       126.000000    126.000000   126.000000       126.000000
# mean          5.404016      5.497540     5.310492         0.978246
# std           1.122353      1.111948     1.133550         0.400156
# min           3.349000      3.461000     3.237000         0.023000
# 25%           4.546250      4.625250     4.396000         0.652750
# 50%           5.302000      5.397500     5.209000         1.060000
# 75%           6.103250      6.190750     6.018750         1.291750
# max           7.537000      7.622000     7.480000         1.633000
#
#         Social support  Healthy life expectancy  Freedom to make life choices  \
# count       126.000000               126.000000                    126.000000
# mean          1.204024                 0.555278                      0.418643
# std           0.269126                 0.235150                      0.137531
# ...

# %%
print(spi.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 27 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   country                               126 non-null    object
#  1   happinessscore                        126 non-null    float64
#  2   whisker-high                          126 non-null    float64
#  3   whisker-low                           126 non-null    float64
#  4   gdppercapita                          126 non-null    float64
#  5   socialsupport                         126 non-null    float64
#  6   healthylifeexpectancy                 126 non-null    float64
#  7   freedomtomakelifechoices              126 non-null    float64
#  8   generosity                            126 non-null    float64
#  9   perceptionsofcorruption               126 non-null    float64
# ...

# %%
spi.isna().sum()
# Out:
# Country                                     0
# Happiness score                             0
# Whisker-high                                0
# Whisker-low                                 0
#  GDP per capita                             0
#  Social support                             0
# Healthy life expectancy                     0
# Freedom to make life choices                0
#  Generosity                                 0
# Perceptions of corruption                   0
# Dystopia (1.85) + residual                  0
# Social Progress Index                       0
# Basic Human Needs                           0
# Foundations of Wellbeing                    0
# Opportunity                                 0
# Nutrition and Basic Medical Care            0
# Water and Sanitation                        0
# Shelter                                     0
# Personal Safety                             0
# Access to Basic Knowledge                   0
# ...

# %%
print("Highet SPI Score : ",spi.max())
# Out:
# Highet SPI Score :  Country                                     Zimbabwe
# Happiness score                                7.537
# Whisker-high                                   7.622
# Whisker-low                                     7.48
#  GDP per capita                                1.633
#  Social support                                1.611
# Healthy life expectancy                        0.913
# Freedom to make life choices                   0.658
#  Generosity                                    0.838
# Perceptions of corruption                      0.455
# Dystopia (1.85) + residual                     3.117
# Social Progress Index                          90.57
# Basic Human Needs                              96.79
# Foundations of Wellbeing                       91.75
# Opportunity                                     88.0
# Nutrition and Basic Medical Care               99.65
# Water and Sanitation                           100.0
# ...

# %%
print( spi.min())
#MIN spi index
# Out:
# Country                                     Afghanistan
# Happiness score                                   3.349
# Whisker-high                                      3.461
# Whisker-low                                       3.237
#  GDP per capita                                   0.023
#  Social support                                   0.432
# Healthy life expectancy                             0.0
# Freedom to make life choices                        0.0
#  Generosity                                         0.0
# Perceptions of corruption                         0.004
# Dystopia (1.85) + residual                        0.378
# Social Progress Index                             28.38
# Basic Human Needs                                 27.82
# Foundations of Wellbeing                          35.41
# Opportunity                                        21.9
# Nutrition and Basic Medical Care                  41.62
# Water and Sanitation                              16.03
# ...

# %%
print(spi.mean())
#mean for the year.
# Out:
# Happiness score                              5.404016
# Whisker-high                                 5.497540
# Whisker-low                                  5.310492
#  GDP per capita                              0.978246
#  Social support                              1.204024
# Healthy life expectancy                      0.555278
# Freedom to make life choices                 0.418643
#  Generosity                                  0.239048
# Perceptions of corruption                    0.117159
# Dystopia (1.85) + residual                   1.891484
# Social Progress Index                       67.633651
# Basic Human Needs                           75.525079
# Foundations of Wellbeing                    72.566111
# Opportunity                                 54.809762
# Nutrition and Basic Medical Care            89.518016
# Water and Sanitation                        74.544206
# Shelter                                     67.956190
# ...

# %%
spi.nunique()
# Out:
# Country                                     126
# Happiness score                             123
# Whisker-high                                122
# Whisker-low                                 123
#  GDP per capita                             121
#  Social support                             118
# Healthy life expectancy                     118
# Freedom to make life choices                105
#  Generosity                                 115
# Perceptions of corruption                    98
# Dystopia (1.85) + residual                  121
# Social Progress Index                       122
# Basic Human Needs                           126
# Foundations of Wellbeing                    124
# Opportunity                                 125
# Nutrition and Basic Medical Care            115
# Water and Sanitation                        121
# Shelter                                     123
# Personal Safety                             124
# Access to Basic Knowledge                   121
# ...

# %%
sns.boxplot(spi['happinessscore'])
# Out:
# C:\Users\kanch\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot: xlabel='happinessscore'>

# %%
spi.duplicated().sum()
# Out:
# 0

# %%
spi.dtypes
# Out:
# Country                                      object
# Happiness score                             float64
# Whisker-high                                float64
# Whisker-low                                 float64
#  GDP per capita                             float64
#  Social support                             float64
# Healthy life expectancy                     float64
# Freedom to make life choices                float64
#  Generosity                                 float64
# Perceptions of corruption                   float64
# Dystopia (1.85) + residual                  float64
# Social Progress Index                       float64
# Basic Human Needs                           float64
# Foundations of Wellbeing                    float64
# Opportunity                                 float64
# Nutrition and Basic Medical Care            float64
# Water and Sanitation                        float64
# Shelter                                     float64
# ...

# %%
spi.corr()
# Out:
#                                           Happiness score  Whisker-high  \
# Happiness score                                  1.000000      0.999640
# Whisker-high                                     0.999640      1.000000
# Whisker-low                                      0.999654      0.998589
#  GDP per capita                                  0.803563      0.801924
#  Social support                                  0.730689      0.731547
# Healthy life expectancy                          0.772899      0.768015
# Freedom to make life choices                     0.496907      0.498654
#  Generosity                                      0.184017      0.183268
# Perceptions of corruption                        0.426784      0.423067
# Dystopia (1.85) + residual                       0.564009      0.566730
# Social Progress Index                            0.361722      0.358041
# Basic Human Needs                                0.319609      0.315998
# ...

# %%
sns.heatmap(spi.corr())
# Out:
# <AxesSubplot: >

# %%
spi[['healthandwellness']].boxplot()
# Out:
# <AxesSubplot: >

# %%
spi.columns=spi.columns.str.replace(' ', '').str.lower()

# %%
df1=spi[['country','gdppercapita']]
top_n1=df1.sort_values('gdppercapita', ascending=False).head(10)


 
fig,ax=plt.subplots()
bar1=ax.bar(top_n1['country'],top_n1['gdppercapita'])
for bars in ax.containers:
    ax.bar_label(bars)
    
ax.set_title('Top 10 countries by gdppercapita')
ax.set_xlabel('Countries')
ax.set_ylabel('GDP per Capita')
plt.xticks(rotation=90)

plt.show()

# %%
df2=spi[['country','happinessscore']]
top_n2=df2.sort_values('happinessscore', ascending=False).head(10)


 
fig,ax=plt.subplots()
bar1=ax.bar(top_n2['country'],top_n2['happinessscore'])
for bars in ax.containers:
    ax.bar_label(bars)
    
ax.set_title('Top 10 countries by happinessscore')
ax.set_xlabel('Countries')
ax.set_ylabel('Happiness Score')
plt.xticks(rotation=90)

plt.show()

# %%
df2=spi[['accesstoadvancededucation','country']]
top_n2=df2.sort_values('accesstoadvancededucation', ascending=False).head(10)


 
fig,ax=plt.subplots()
bar1=ax.bar(top_n2['accesstoadvancededucation'],top_n2['country'])
for bars in ax.containers:
    ax.bar_label(bars)
    
ax.set_title('Top 10 score')
ax.set_xlabel('Access to Advanced Education')
ax.set_ylabel('Country')
plt.xticks(rotation=90)

plt.show()
